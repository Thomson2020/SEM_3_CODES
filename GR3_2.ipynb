# %% [markdown]
# <a href="https://colab.research.google.com/github/Thomson2020/SEM_3_CODES/blob/main/GR3_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

from einsteinpy.geodesic import Nulllike
from einsteinpy.plotting import StaticGeodesicPlotter

position = [2.5, np.pi / 2, 0.]
momentum = [0., 0., -2.]
a = 0.99
steps = 7440  # As close as we can get before the integration becomes highly unstable
delta = 0.0005
omega = 0.01
suppress_warnings = True

geod = Nulllike(
    metric="Kerr",
    metric_params=(a,),
    position=position,
    momentum=momentum,
    steps=steps,
    delta=delta,
    return_cartesian=True,
    omega=omega,
    suppress_warnings=suppress_warnings
)
sgpl = StaticGeodesicPlotter(bh_colors=("red", "blue"))
sgpl.plot2D(geod, coordinates=(1, 2), figsize=(10, 10), color="indigo") # Plot X vs Y
sgpl.show()

# %%
# !pip install einsteinpy
# Out:
# Collecting einsteinpy
#   Downloading einsteinpy-0.4.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from einsteinpy) (1.25.2)
# Requirement already satisfied: astropy in /usr/local/lib/python3.10/dist-packages (from einsteinpy) (6.1.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from einsteinpy) (3.7.1)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.10/dist-packages (from einsteinpy) (1.13.1)
# Requirement already satisfied: plotly>=4.0 in /usr/local/lib/python3.10/dist-packages (from einsteinpy) (5.15.0)
# Requirement already satisfied: sympy>=1.1 in /usr/local/lib/python3.10/dist-packages (from einsteinpy) (1.13.1)
# Requirement already satisfied: numba!=0.49.0,>=0.46 in /usr/local/lib/python3.10/dist-packages (from einsteinpy) (0.60.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba!=0.49.0,>=0.46->einsteinpy) (0.43.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly>=4.0->einsteinpy) (8.5.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from plotly>=4.0->einsteinpy) (24.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy>=1.1->einsteinpy) (1.3.0)
# Requirement already satisfied: pyerfa>=2.0.1.1 in /usr/local/lib/python3.10/dist-packages (from astropy->einsteinpy) (2.0.1.4)
# Requirement already satisfied: astropy-iers-data>=0.2024.7.1.0.34.3 in /usr/local/lib/python3.10/dist-packages (from astropy->einsteinpy) (0.2024.7.22.0.34.13)
# Requirement already satisfied: PyYAML>=3.13 in /usr/local/lib/python3.10/dist-packages (from astropy->einsteinpy) (6.0.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->einsteinpy) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->einsteinpy) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->einsteinpy) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->einsteinpy) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->einsteinpy) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->einsteinpy) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->einsteinpy) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->einsteinpy) (1.16.0)
# Downloading einsteinpy-0.4.0-py3-none-any.whl (88 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.1/88.1 kB 4.4 MB/s eta 0:00:00
# Installing collected packages: einsteinpy
# Successfully installed einsteinpy-0.4.0
